# %% [markdown]
# <a href="https://colab.research.google.com/github/coldtomato/pythonbasicclass2/blob/main/PythonBasicDay4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Input
# n = input('정수를 입력하세요')
# print(type(n))#input은 무조건 문자열str이다.

#단,
# n= int(input('정수를 입력하세요'))
# print(type(n))# <class 'int'>로 변환되었다.따라서 숫자로 입력을 받기 위해서는 casting을 하여 숫자로 바꾼다.\

# price = 50000
# a = int(input('할부 개월 입력>>>'))
# print('매달 내는 돈은 {}입니다.'.format(price/n))

#1번
# a = int(input(' 첫번째 실수를 입력하세요 >>>'))
# b = int(input(' 두번째 실수를 입력하세요 >>>'))

# print(f'{a}와 {b}의 합은 {a+b}입니다')
############################################숫자입력시 형변환은 필수다.

# a = float(input(' 첫번째 실수를 입력하세요 >>>'))
# b = float(input(' 두번째 실수를 입력하세요 >>>'))

# print(f'{a}와 {b}의 합은 {a+b}입니다')

#2번
# month = [0,31,28,31,30,31,30,31,31,30,31,30,31]


# a= int(input('1~12월사이의 월을 입력하세요 >>>'))
# print(f'{a}월은 {month[a]}일까지 있습니다.')

#또는
# month = [31,28,31,30,31,30,31,31,30,31,30,31]


# a= int(input('1~12월사이의 월을 입력하세요 >>>'))
# print(f'{a}월은 {month[a-1]}일까지 있습니다.')

#3번
# english_dict = {'flower':'꽃', 'fly':'날다', 'floor':'바닥'}
# word = input('영어 단어를 입력하세요>>>')
# print(f'{word}:{english_dict[word]}')

#복합 대입 연산자
# a -= 1
# print(a)
# a += 1
# print(a)

#변수 교환
# a, b = 10, 20
# print('a = %d, b = %d' % (a,b)) 


# a, b = b, a
# print('a = %d, b = %d' % (a,b)) # 교환하는 방법1

# t = a
# a = b
# b = t
# print('a = %d, b = %d' % (a,b)) # 교환하는 방법2

# 1 == 1 # True
# 1 != 1 # False 같지 않다.

# 시퀀스 연산자 
# [1, 3, 5] + [2, 4, 6]#리스트를 합친다\
# [1, 3, 5] * 2
# ['hello'] + [' ','python']
# ['봄']*20

#84p 까지

# 멤버쉽 연산자
# 5 in [1,2,3,4,5] #5가 리스트에 있는지 확인해준다.
# 5 not in[1,2,3,4,5] #5가 리스트에 없다.False
# 'a' in 'apple'

# 'a' in {'a' : 'apple', 'b' : 'banana'}

#4-1 연습문제 첫번째 풀이
# number = int(input('10~99 사이의 정수를 입력하세요 >>>'))
# t = number // 10 # 몫만 취하는 연산
# b = number % 10 # 나머지만 취하는 연산
# print('십의 자리 :{}' .format(t))
# print('일의 자리 :{}' .format(b))

#4-1연습문제 두번째 풀이
# no = input('10~99 사이의 정수를 입력하세요 >>>')
# print(f'십의 자리 : {no[0]}')
# print(f'십의 자리 : {no[1]}')

#4-2연습문제 첫번째 풀이
# ti = int(input('초를 입력하세요 >>>'))
# h = ti // 3600
# m = ti % 3600 // 60
# s = ti % 60
# print('변환 결과는 {}시간 {}분 {}초입니다.'.format(h, m, s))

#4-3 연습문제
# cono = int(input('사원번호 네자리를 입력하세요 >>>')) #사원번호 끝자리 5이상 오전 5이하 오후
# cono_1 = cono % 10
# if cono_1 >= 5:
#   print('근무시간은 오전입니다.')
# else:
#   print('근무시간은 오후입니다.')

# #print('당신의 근무시간은 {}입니다.')

# money = False
# if money:
#   print("택시를 타고 가라")
# else:
#   print("걸어 가라")

#숙제
print("Mary's cosmetics")#2번
print('신씨가 소리질렀다. "도둑이야"')#3번
print(str('"C:/Windows"'))#4번
print('안녕하세요.\n 만나서 반갑습니다.')
# Out:
# Mary's cosmetics
# 신씨가 소리질렀다. "도둑이야"
# "C:/Windows"
# 안녕하세요.
#  만나서 반갑습니다.
